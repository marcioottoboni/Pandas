# %% [markdown]
# # <img src="https://media.licdn.com/dms/image/v2/D4D12AQHlIsAcP91v6A/article-cover_image-shrink_720_1280/article-cover_image-shrink_720_1280/0/1725880873576?e=2147483647&v=beta&t=6KoRRFcljZhQxpXMmYq4sE2aKeOJ49J6Qi3iQJfG6KM" width="190"  align="right">
#
# <div align="center" style="font-size:40px; font-weight:bold;">
#     Manipulando uma Serie
# </div>

# %% [markdown]
# <hr style="height:4px;border:none;background-color:black;">

# %% [markdown]
# ## Importando a biblioteca e  criando os assets.

# %%
import pandas as pd

# %%
pokemon = pd.read_csv("/Users/user/Documents/GitHub/Python_Dados/data-analysis-with-pandas-and-python/Incomplete/pokemon.csv", usecols=["Name"]).squeeze("columns")
google = pd.read_csv("/Users/user/Documents/GitHub/Python_Dados/data-analysis-with-pandas-and-python/Incomplete/google_stock_prices.csv", usecols=["Price"]).squeeze("columns")

# %% [markdown]
# ## Sobrepondo um valor da Serie

# %%
pokemon.iloc[0] = "Bulbasauro"

# %%
# Out:
# '3.0.3'
